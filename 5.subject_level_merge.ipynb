# %%
import os
import pandas as pd
import numpy as np

# %%
derivs_dir = os.path.join('..','derivatives')
scales_dir = os.path.join(derivs_dir,'qualtrics','2.subscaled')
output_dir = os.path.join(derivs_dir,'05.subject-level')

# %%
try:os.mkdir(output_dir)
except WindowsError as e: print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: '..\\derivatives\\05.subject-level'

# %% [markdown]
# # Import data

# %%
fname=os.path.join(derivs_dir,'sub-all_task-all_VALUES.xlsx')
behav_data = pd.read_excel(fname).rename(columns={'subjnum':'ssid'})

# %%
fname=os.path.join(scales_dir,'all_subscales.csv')
scale_data = pd.read_csv(fname)

# %%
behav_data.head()
# Out:
#    study  ssid  block  trial domain  binary-domain estimation  trueprob  \
# 0      1   100      1      1   LOSS             -1         50  0.300000
# 1      1   100      1      2   LOSS             -1         30  0.155172
# 2      1   100      1      3   LOSS             -1         30  0.300000
# 3      1   100      1      4   LOSS             -1         40  0.500000
# 4      1   100      1      5   LOSS             -1         60  0.700000
#
#    trueprob-norm   val-estdiff         ...          facemem-split-123  \
# 0       0.300000  2.000001e-01         ...                       -1.0
# 1       0.155172  1.448277e-01         ...                        1.0
# 2       0.300000  1.038193e-07         ...                        NaN
# 3       0.500000 -1.000000e-01         ...                        NaN
# 4       0.700000 -1.000001e-01         ...                       -1.0
#
#    facemem-median-123  choice-split-12  outcome-split-12  choice-split-123  \
# 0                   2              1.0               1.0               1.0
# 1                   2              NaN               1.0               NaN
# 2                   2              1.0               1.0               1.0
# 3                   2              1.0               1.0               1.0
# 4                   2             -1.0               1.0              -1.0
#
#    outcome-split-123  choice-median-12  outcome-median-12  choice-median-123  \
# 0                1.0          2.899986           2.378043           2.798163
# 1                1.0               NaN                NaN           2.798163
# 2                1.0               NaN                NaN           2.798163
# 3                1.0               NaN                NaN           2.798163
# 4                1.0               NaN                NaN           2.798163
#
#    outcome-median-123
# 0            2.296676
# 1            2.296676
# 2            2.296676
# 3            2.296676
# 4            2.296676
#
# [5 rows x 57 columns]

# %%
scale_data.head()
# Out:
#    ssid    ZIP  Relative Sleep  Relative Stress  Financial Difficulty   PAS  \
# 0   201  00233            -1.0              1.0                     1  32.0
# 1   202  34109             0.0             -1.0                     0  39.0
# 2   203  33071            -1.0              0.0                     0  33.0
# 3   146  32828             0.0              0.0                     0  36.0
# 4   205  33027            -1.0             -1.0                     1  26.0
#
#     NAS  BAS Drive  BAS Fun Seeking  BAS Reward Responsiveness   BIS  \
# 0  17.0       12.0              8.0                       20.0  20.0
# 1  10.0       13.0             15.0                       20.0  16.0
# 2  13.0       13.0             13.0                       20.0  25.0
# 3  15.0       12.0             11.0                       17.0  21.0
# 4  25.0       14.0             12.0                       19.0  24.0
#
#    Intuitive DMS  Rational DMS  Dependent DMS  Spontaneous DMS  Avoidant DMS  \
# 0           18.0          22.0           21.0             11.0          16.0
# 1           24.0          25.0            8.0             15.0           9.0
# 2           18.0          20.0           25.0             15.0          23.0
# 3           16.0          22.0           17.0              7.0          13.0
# 4           23.0          23.0           22.0             14.0          14.0
#
#    Financial Literacy
# 0                 1.0
# 1                 1.0
# 2                 1.0
# 3                 0.0
# 4                 2.0

# %% [markdown]
# # Normalize PANAS and BISBAS subscales

# %%
keys_to_normalize = [
    'PAS','NAS','BIS','BAS_fs','BAS_rr','BAS_dr','DMS_i','DMS_r','DMS_d','DMS_s','DMS_a',
]

# %%
df = scale_data.copy(deep=True)
df.columns=[
    'ssid','zip','sleep','stress','fin_dif','PAS','NAS','BAS_dr','BAS_fs','BAS_rr','BIS',
    'DMS_i','DMS_r','DMS_d','DMS_s','DMS_a','fin_lit'
]

# %%
df['study'] = df['ssid'].astype(str).str[0]

# %%
from clean import normalize

# %%
z_keys=[]
for key in keys_to_normalize:
    z_key = 'z_'+ key
    z_keys.append(z_key)
    df[z_key] = df.apply(normalize,axis=1)

# %%
df.head()
# Out:
#    ssid    zip  sleep  stress  fin_dif   PAS   NAS  BAS_dr  BAS_fs  BAS_rr  \
# 0   201  00233   -1.0     1.0        1  32.0  17.0    12.0     8.0    20.0
# 1   202  34109    0.0    -1.0        0  39.0  10.0    13.0    15.0    20.0
# 2   203  33071   -1.0     0.0        0  33.0  13.0    13.0    13.0    20.0
# 3   146  32828    0.0     0.0        0  36.0  15.0    12.0    11.0    17.0
# 4   205  33027   -1.0    -1.0        1  26.0  25.0    14.0    12.0    19.0
#
#      ...        z_NAS     z_BIS  z_BAS_fs  z_BAS_rr  z_BAS_dr   z_DMS_i  \
# 0    ...     0.719199 -0.328343 -1.917315  0.954217  0.208641 -0.033542
# 1    ...    -0.830939 -1.429557  1.249160  0.954217  0.654561  1.653886
# 2    ...    -0.166594  1.048173  0.344453  0.954217  0.654561 -0.033542
# 3    ...     0.778937  0.103462 -0.924831 -0.601536 -0.004402 -0.521983
# 4    ...     2.490786  0.772870 -0.107901  0.316121  1.100481  1.372648
#
#     z_DMS_r   z_DMS_d   z_DMS_s   z_DMS_a
# 0  0.434326  0.537998 -0.586269  0.494748
# 1  1.494209 -2.719881  0.396859 -0.839148
# 2 -0.272264  1.540423  0.396859  1.828644
# 3  0.606033 -0.493360 -1.632707 -0.128144
# 4  0.787620  0.788605  0.151077  0.113635
#
# [5 rows x 29 columns]

# %%
columns = z_keys + ['ssid']
norms = df[columns]
norms.head()
# Out:
#       z_PAS     z_NAS     z_BIS  z_BAS_fs  z_BAS_rr  z_BAS_dr   z_DMS_i  \
# 0 -0.060217  0.719199 -0.328343 -1.917315  0.954217  0.208641 -0.033542
# 1  0.877450 -0.830939 -1.429557  1.249160  0.954217  0.654561  1.653886
# 2  0.073735 -0.166594  1.048173  0.344453  0.954217  0.654561 -0.033542
# 3  0.641580  0.778937  0.103462 -0.924831 -0.601536 -0.004402 -0.521983
# 4 -0.863932  2.490786  0.772870 -0.107901  0.316121  1.100481  1.372648
#
#     z_DMS_r   z_DMS_d   z_DMS_s   z_DMS_a  ssid
# 0  0.434326  0.537998 -0.586269  0.494748   201
# 1  1.494209 -2.719881  0.396859 -0.839148   202
# 2 -0.272264  1.540423  0.396859  1.828644   203
# 3  0.606033 -0.493360 -1.632707 -0.128144   146
# 4  0.787620  0.788605  0.151077  0.113635   205

# %% [markdown]
# ### Natural Logarithm of subscales

# %% [markdown]
# We take the natural log of each subscale's RAW score.
#
# *NOT* their normalized score, because we can't take the log of a negative.

# %%
ln_keys = ['ln_'+key for key in keys_to_normalize]
df[ln_keys] = df[keys_to_normalize].apply(np.log,axis=1)
df.head()
# Out:
#    ssid    zip  sleep  stress  fin_dif   PAS   NAS  BAS_dr  BAS_fs  BAS_rr  \
# 0   201  00233   -1.0     1.0        1  32.0  17.0    12.0     8.0    20.0
# 1   202  34109    0.0    -1.0        0  39.0  10.0    13.0    15.0    20.0
# 2   203  33071   -1.0     0.0        0  33.0  13.0    13.0    13.0    20.0
# 3   146  32828    0.0     0.0        0  36.0  15.0    12.0    11.0    17.0
# 4   205  33027   -1.0    -1.0        1  26.0  25.0    14.0    12.0    19.0
#
#      ...       ln_NAS    ln_BIS  ln_BAS_fs  ln_BAS_rr  ln_BAS_dr  ln_DMS_i  \
# 0    ...     2.833213  2.995732   2.079442   2.995732   2.484907  2.890372
# 1    ...     2.302585  2.772589   2.708050   2.995732   2.564949  3.178054
# 2    ...     2.564949  3.218876   2.564949   2.995732   2.564949  2.890372
# 3    ...     2.708050  3.044522   2.397895   2.833213   2.484907  2.772589
# 4    ...     3.218876  3.178054   2.484907   2.944439   2.639057  3.135494
#
#    ln_DMS_r  ln_DMS_d  ln_DMS_s  ln_DMS_a
# 0  3.091042  3.044522  2.397895  2.772589
# 1  3.218876  2.079442  2.708050  2.197225
# 2  2.995732  3.218876  2.708050  3.135494
# 3  3.091042  2.833213  1.945910  2.564949
# 4  3.135494  3.091042  2.639057  2.639057
#
# [5 rows x 40 columns]

# %%
logs = df[ln_keys + ['ssid']]
logs.head()
# Out:
#      ln_PAS    ln_NAS    ln_BIS  ln_BAS_fs  ln_BAS_rr  ln_BAS_dr  ln_DMS_i  \
# 0  3.465736  2.833213  2.995732   2.079442   2.995732   2.484907  2.890372
# 1  3.663562  2.302585  2.772589   2.708050   2.995732   2.564949  3.178054
# 2  3.496508  2.564949  3.218876   2.564949   2.995732   2.564949  2.890372
# 3  3.583519  2.708050  3.044522   2.397895   2.833213   2.484907  2.772589
# 4  3.258097  3.218876  3.178054   2.484907   2.944439   2.639057  3.135494
#
#    ln_DMS_r  ln_DMS_d  ln_DMS_s  ln_DMS_a  ssid
# 0  3.091042  3.044522  2.397895  2.772589   201
# 1  3.218876  2.079442  2.708050  2.197225   202
# 2  2.995732  3.218876  2.708050  3.135494   203
# 3  3.091042  2.833213  1.945910  2.564949   146
# 4  3.135494  3.091042  2.639057  2.639057   205

# %% [markdown]
# # 3sd trial exclusions

# %%
behav_data.columns
# Out:
# Index(['study', 'ssid', 'block', 'trial', 'domain', 'binary-domain',
#        'estimation', 'trueprob', 'trueprob-norm', 'val-estdiff',
#        'val-estdiff-valid', 'val-estdiff-valid-mc-12',
#        'val-estdiff-valid-mc-123', 'abs-estdiff', 'abs-estdiff-valid',
#        'abs-estdiffvalid-mc-12', 'abs-estdiff-valid-mc-123', 'choicert',
#        'choicert-3sd-12', 'choicert-3sd-123', 'choicert-mc-12',
#        'choicert-mc-123', 'esttaskrt', 'esttaskrt-3sd-12', 'esttaskrt-3sd-123',
#        'outcomert', 'outcomert-3sd-12', 'outcomert-3sd-123', 'outcomert-mc-12',
#        'outcomert-mc-123', 'stockchosen', 'waschoiceoptimal',
#        'optimalchoicewas', 'stockvalue', 'abs-stockvalue',
#        'bin-abs-stockvalue', 'bin-abs-stockvalue-mc-12',
#        'bin-abs-stockvalue-mc-123', 'b4choiceprob', 'stockpic', 'bondpic',
#        'facepic', 'bondmem', 'stockmem', 'facemem', 'facemem-clean-reverse',
#        'facemem-mc-123', 'facemem-split-123', 'facemem-median-123',
#        'choice-split-12', 'outcome-split-12', 'choice-split-123',
#        'outcome-split-123', 'choice-median-12', 'outcome-median-12',
#        'choice-median-123', 'outcome-median-123'],
#       dtype='object')

# %%
df=behav_data[['ssid','block','trial','domain','estimation','trueprob-norm','waschoiceoptimal','val-estdiff-valid']].rename(
    columns={'val-estdiff-valid':'val_estdiff_valid'}
)

# %%
subj_3sd = df.groupby('ssid').std()['val_estdiff_valid'] * 3
subj_3sd.head()
# Out:
# ssid
# 100    0.548469
# 101    0.262039
# 102    0.358415
# 103    0.620042
# 104    0.809025
# Name: val_estdiff_valid, dtype: float64

# %%
subj_means = df.groupby('ssid').mean()['val_estdiff_valid']
subj_means.head()
# Out:
# ssid
# 100    0.046724
# 101   -0.014427
# 102    0.014467
# 103    0.036173
# 104    0.070082
# Name: val_estdiff_valid, dtype: float64

# %%
from clean import exclude_3sd

# %%
df['valError_3sd'] = df.apply(exclude_3sd,axis=1)
df.head()
# Out:
#    ssid  block  trial domain estimation  trueprob-norm  waschoiceoptimal  \
# 0   100      1      1   LOSS         50       0.300000               NaN
# 1   100      1      2   LOSS         30       0.155172               1.0
# 2   100      1      3   LOSS         30       0.300000               1.0
# 3   100      1      4   LOSS         40       0.500000               1.0
# 4   100      1      5   LOSS         60       0.700000               NaN
#
#    val_estdiff_valid  valError_3sd
# 0       2.000001e-01  2.000001e-01
# 1       1.448277e-01  1.448277e-01
# 2       1.038193e-07  1.038193e-07
# 3      -1.000000e-01 -1.000000e-01
# 4      -1.000001e-01 -1.000001e-01

# %%
subj_means = df.groupby('ssid').mean()['valError_3sd']
subj_means = pd.DataFrame(subj_means).reset_index()
subj_means.head()
# Out:
#    ssid  valError_3sd
# 0   100      0.046724
# 1   101     -0.014427
# 2   102      0.012664
# 3   103      0.036173
# 4   104      0.070082

# %% [markdown]
# # gender-judgment trial exclusions

# %% [raw]
# We don't have the gender judgment data in the source file for this notebook, but this is where I want to exclude trials in which the gender judgment was wrong. Have to go further upstream to include the gender judgment in this source file, then apply the gender judgment exclusion here.

# %% [markdown]
# # subject-level means

# %%
optimal_choice_freq = df.groupby('ssid').mean().reset_index()[['ssid','waschoiceoptimal']]
optimal_choice_freq.head()
# Out:
#    ssid  waschoiceoptimal
# 0   100          0.886792
# 1   101          0.711538
# 2   102          0.592593
# 3   103          0.415094
# 4   104          0.581818

# %%
domain_means = df.groupby(['ssid','domain']).mean().reset_index()
domain_means.head()
# Out:
#    ssid domain     block  trial  trueprob-norm  waschoiceoptimal  \
# 0   100   GAIN  6.666667   37.5       0.333548          0.827586
# 1   100   LOSS  6.333333   35.5       0.473004          0.958333
# 2   101   GAIN  7.500000   42.5       0.552187          0.827586
# 3   101   LOSS  5.500000   30.5       0.500000          0.565217
# 4   102   GAIN  8.000000   45.5       0.420043          0.571429
#
#    val_estdiff_valid  valError_3sd
# 0           0.102563      0.102563
# 1          -0.009115     -0.009115
# 2           0.003091      0.003091
# 3          -0.031944     -0.031944
# 4           0.034123      0.034123

# %%
gain_ave_val_error = domain_means[domain_means['domain'] == 'GAIN'][['ssid','valError_3sd']]
gain_ave_val_error = gain_ave_val_error.set_index('ssid')

# %%
loss_ave_val_error = domain_means[domain_means['domain'] == 'LOSS'][['ssid','valError_3sd']]
loss_ave_val_error = loss_ave_val_error.set_index('ssid')

# %% [markdown]
# ### Framing Normalization
# We want to normalize for the way the value estimation question is framed.
#
# We're going to multiply valError means by `1` for subjects who were estimating the probability that the stock is *good*, and multiply means by `-1` for subjects who were estimating the probability that the stock is *bad*.
#
# 100s: `*  1`
#
# 200s: `* -1`
#
# 300s: `*  1`

# %%
from clean import normalize_frame

# %%
means_df = df.groupby('ssid').mean()[['valError_3sd']]
means_df[85:91]
# Out:
#       valError_3sd
# ssid
# 188      -0.015131
# 190       0.011036
# 191       0.031606
# 202      -0.026935
# 203       0.015476
# 204       0.022662

# %%
nf_valerror = pd.DataFrame(means_df.apply(normalize_frame,axis=1))
nf_valerror = nf_valerror.rename(columns={0:'nf_valError'})
nf_valerror[85:91]
# Out:
#       nf_valError
# ssid
# 188     -0.015131
# 190      0.011036
# 191      0.031606
# 202      0.026935
# 203     -0.015476
# 204     -0.022662

# %%
gain_ave_val_error[85:91]
# Out:
#       valError_3sd
# ssid
# 188      -0.005284
# 190       0.069810
# 191       0.018383
# 202      -0.022684
# 203      -0.025620
# 204       0.003329

# %%
nf_valerr_gain = pd.DataFrame(gain_ave_val_error.apply(normalize_frame,axis=1))
nf_valerr_gain = nf_valerr_gain.rename(columns={0:'nf_gainValError'})
nf_valerr_gain[85:91]
# Out:
#       nf_gainValError
# ssid
# 188         -0.005284
# 190          0.069810
# 191          0.018383
# 202          0.022684
# 203          0.025620
# 204         -0.003329

# %%
loss_ave_val_error[85:91]
# Out:
#       valError_3sd
# ssid
# 188      -0.024704
# 190      -0.047737
# 191       0.044094
# 202      -0.031186
# 203       0.056573
# 204       0.041995

# %%
nf_valerr_loss = pd.DataFrame(loss_ave_val_error.apply(normalize_frame,axis=1))
nf_valerr_loss = nf_valerr_loss.rename(columns={0:'nf_lossValError'})
nf_valerr_loss[85:91]
# Out:
#       nf_lossValError
# ssid
# 188         -0.024704
# 190         -0.047737
# 191          0.044094
# 202          0.031186
# 203         -0.056573
# 204         -0.041995

# %% [markdown]
# # output

# %%
output = pd.DataFrame({
    'ssid':list(subj_means['ssid']),
    'valError':list(subj_means['valError_3sd']),
})
output.head()
# Out:
#    ssid  valError
# 0   100  0.046724
# 1   101 -0.014427
# 2   102  0.012664
# 3   103  0.036173
# 4   104  0.070082

# %%
output = output.merge(optimal_choice_freq).rename(columns={'waschoiceoptimal':'optimal_choice_freq'})
output.head()
# Out:
#    ssid  valError  optimal_choice_freq
# 0   100  0.046724             0.886792
# 1   101 -0.014427             0.711538
# 2   102  0.012664             0.592593
# 3   103  0.036173             0.415094
# 4   104  0.070082             0.581818

# %%
output = output.merge(gain_ave_val_error.rename(columns={'valError_3sd':'gainValError'}).reset_index())
output.head()
# Out:
#    ssid  valError  optimal_choice_freq  gainValError
# 0   100  0.046724             0.886792      0.102563
# 1   101 -0.014427             0.711538      0.003091
# 2   102  0.012664             0.592593      0.034123
# 3   103  0.036173             0.415094      0.097953
# 4   104  0.070082             0.581818      0.133293

# %%
output = output.merge(loss_ave_val_error.rename(columns={'valError_3sd':'lossValError'}).reset_index())
output.head()
# Out:
#    ssid  valError  optimal_choice_freq  gainValError  lossValError
# 0   100  0.046724             0.886792      0.102563     -0.009115
# 1   101 -0.014427             0.711538      0.003091     -0.031944
# 2   102  0.012664             0.592593      0.034123     -0.010058
# 3   103  0.036173             0.415094      0.097953     -0.025607
# 4   104  0.070082             0.581818      0.133293      0.006871

# %%
output = output.merge(nf_valerror.reset_index())
output = output.merge(nf_valerr_gain.reset_index())
output = output.merge(nf_valerr_loss.reset_index())
output[85:91]
# Out:
#     ssid  valError  optimal_choice_freq  gainValError  lossValError  \
# 85   188 -0.015131             0.764706     -0.005284     -0.024704
# 86   190  0.011036             0.411765      0.069810     -0.047737
# 87   191  0.031606             0.886792      0.018383      0.044094
# 88   202 -0.026935             0.833333     -0.022684     -0.031186
# 89   203  0.015476             0.872727     -0.025620      0.056573
# 90   204  0.022662             0.620000      0.003329      0.041995
#
#     nf_valError  nf_gainValError  nf_lossValError
# 85    -0.015131        -0.005284        -0.024704
# 86     0.011036         0.069810        -0.047737
# 87     0.031606         0.018383         0.044094
# 88     0.026935         0.022684         0.031186
# 89    -0.015476         0.025620        -0.056573
# 90    -0.022662        -0.003329        -0.041995

# %%
output['valWedge'] = abs(output['gainValError'] - output['lossValError'])
output['nf_valWedge'] = abs(output['nf_gainValError'] - output['nf_lossValError'])
output.head()
# Out:
#    ssid  valError  optimal_choice_freq  gainValError  lossValError  \
# 0   100  0.046724             0.886792      0.102563     -0.009115
# 1   101 -0.014427             0.711538      0.003091     -0.031944
# 2   102  0.012664             0.592593      0.034123     -0.010058
# 3   103  0.036173             0.415094      0.097953     -0.025607
# 4   104  0.070082             0.581818      0.133293      0.006871
#
#    nf_valError  nf_gainValError  nf_lossValError  valWedge  nf_valWedge
# 0     0.046724         0.102563        -0.009115  0.111678     0.111678
# 1    -0.014427         0.003091        -0.031944  0.035036     0.035036
# 2     0.012664         0.034123        -0.010058  0.044181     0.044181
# 3     0.036173         0.097953        -0.025607  0.123560     0.123560
# 4     0.070082         0.133293         0.006871  0.126422     0.126422

# %%
output = output.merge(norms)
output.head()
# Out:
#    ssid  valError  optimal_choice_freq  gainValError  lossValError  \
# 0   100  0.046724             0.886792      0.102563     -0.009115
# 1   101 -0.014427             0.711538      0.003091     -0.031944
# 2   102  0.012664             0.592593      0.034123     -0.010058
# 3   103  0.036173             0.415094      0.097953     -0.025607
# 4   104  0.070082             0.581818      0.133293      0.006871
#
#    nf_valError  nf_gainValError  nf_lossValError  valWedge  nf_valWedge  \
# 0     0.046724         0.102563        -0.009115  0.111678     0.111678
# 1    -0.014427         0.003091        -0.031944  0.035036     0.035036
# 2     0.012664         0.034123        -0.010058  0.044181     0.044181
# 3     0.036173         0.097953        -0.025607  0.123560     0.123560
# 4     0.070082         0.133293         0.006871  0.126422     0.126422
#
#      ...        z_NAS     z_BIS  z_BAS_fs  z_BAS_rr  z_BAS_dr   z_DMS_i  \
# 0    ...    -0.617778  1.375766  0.987888  1.074172 -0.004402  1.346013
# 1    ...    -0.966957 -0.914381  0.987888  0.515603  0.796675  0.545443
# 2    ...    -0.966957  0.612383  0.987888 -0.042967 -0.805478 -1.322553
# 3    ...     0.080580  0.612383  0.987888  1.074172  1.197213  1.612869
# 4    ...     0.778937  0.103462  1.466068  0.515603  0.396137  0.278587
#
#     z_DMS_r   z_DMS_d   z_DMS_s   z_DMS_a
# 0  0.907394  1.091196  1.334255 -1.207880
# 1 -1.503493 -0.229267  1.562483  1.167539
# 2  0.003312 -0.229267  0.421344 -0.991933
# 3  1.208755  0.563010  0.649572  0.735644
# 4 -1.503493 -0.493360  1.334255 -0.344092
#
# [5 rows x 21 columns]

# %%
output = output.merge(logs)
output.head()
# Out:
#    ssid  valError  optimal_choice_freq  gainValError  lossValError  \
# 0   100  0.046724             0.886792      0.102563     -0.009115
# 1   101 -0.014427             0.711538      0.003091     -0.031944
# 2   102  0.012664             0.592593      0.034123     -0.010058
# 3   103  0.036173             0.415094      0.097953     -0.025607
# 4   104  0.070082             0.581818      0.133293      0.006871
#
#    nf_valError  nf_gainValError  nf_lossValError  valWedge  nf_valWedge  \
# 0     0.046724         0.102563        -0.009115  0.111678     0.111678
# 1    -0.014427         0.003091        -0.031944  0.035036     0.035036
# 2     0.012664         0.034123        -0.010058  0.044181     0.044181
# 3     0.036173         0.097953        -0.025607  0.123560     0.123560
# 4     0.070082         0.133293         0.006871  0.126422     0.126422
#
#      ...       ln_NAS    ln_BIS  ln_BAS_fs  ln_BAS_rr  ln_BAS_dr  ln_DMS_i  \
# 0    ...     2.397895  3.258097   2.708050   2.995732   2.484907  3.135494
# 1    ...     2.302585  2.833213   2.708050   2.944439   2.639057  2.995732
# 2    ...     2.302585  3.135494   2.708050   2.890372   2.302585  2.564949
# 3    ...     2.564949  3.135494   2.708050   2.995732   2.708050  3.178054
# 4    ...     2.708050  3.044522   2.772589   2.944439   2.564949  2.944439
#
#    ln_DMS_r  ln_DMS_d  ln_DMS_s  ln_DMS_a
# 0  3.135494  3.135494  2.995732  2.079442
# 1  2.708050  2.890372  3.044522  2.944439
# 2  2.995732  2.890372  2.772589  2.197225
# 3  3.178054  3.044522  2.833213  2.833213
# 4  2.708050  2.833213  2.995732  2.484907
#
# [5 rows x 32 columns]

# %%
fname=os.path.join(output_dir,'subject-level.csv')
#columns = ['ssid','valError','gainValError','lossValError','valWedge'] + zkeys
output.to_csv(fname,index=False)
