# %%
import os
import numpy as np
import pandas as pd
input_dir = os.path.join('..','derivatives','qualtrics','1.merge')
output_dir= os.path.join('..','derivatives','qualtrics','2.subscaled')

# %%
frames={}
for fname in os.listdir(input_dir):
    print(fname)
    fpath = os.path.join(input_dir,fname)
    frames[fname.split('.')[0]] = pd.read_csv(fpath).drop(columns='Finished')
# Out:
# bisbas.csv
# demog.csv
# financ.csv
# gdms.csv
# panas.csv

# %%
frames.keys()
# Out:
# ['financ', 'panas', 'demog', 'bisbas', 'gdms']

# %% [markdown]
# # Demographics

# %%
frames['demog'].head()
# Out:
#    Participant Number:  How old are you?  What is your gender?  \
# 0                  201              20.0                   1.0
# 1                  202              19.0                   2.0
# 2                  203              19.0                   2.0
# 3                  146              18.0                   1.0
# 4                  205              23.0                   1.0
#
#    How many years of education have you received, including grade school? (12 = HS diploma, 16 = Bachelor’s degree)  \
# 0                                               14.0
# 1                                               14.0
# 2                                               12.0
# 3                                               13.0
# 4                                               16.0
#
#    Please indicate your ethnicity:  \
# 0                              2.0
# 1                              1.0
# 2                              2.0
# 3                              1.0
# 4                              1.0
#
#   Please indicate your race (select all that apply): - Selected Choice  \
# 0                                                  1
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#   Please indicate your race (select all that apply): - Multi-racial/Other: - Text  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is your profession? If retired, please state your former profession:  \
# 0                                            Student
# 1                                            Student
# 2                                    Sales Associate
# 3                                            Student
# 4                                         programmer
#
#    How would you describe your overall health, on a scale from 1 to 9? - 1  \
# 0                                                8.0
# 1                                                8.0
# 2                                                9.0
# 3                                                9.0
# 4                                                6.0
#
#    During which time of day do you function best and feel most alert?  \
# 0                                                2.0
# 1                                                4.0
# 2                                                4.0
# 3                                                2.0
# 4                                                3.0
#
#    How many hours did you sleep last night?  \
# 0                                       7.0
# 1                                       8.0
# 2                                       6.0
# 3                                       8.0
# 4                                       7.0
#
#   How many hours do you usually sleep each night?  \
# 0                                             7.5
# 1                                               8
# 2                                               8
# 3                                               8
# 4                                             8.5
#
#    What do you feel your stress level is today on a scale from 1 to 9?  \
# 0                                                7.0
# 1                                                1.0
# 2                                                2.0
# 3                                                2.0
# 4                                                5.0
#
#    How does your stress level today compare with your usual stress level?  \
# 0                                                7.0
# 1                                                3.0
# 2                                                5.0
# 3                                                5.0
# 4                                                2.0
#
#    What is your family’s/parents’ combined annual income? Please choose:  \
# 0                                                1.0
# 1                                                4.0
# 2                                                6.0
# 3                                                7.0
# 4                                                5.0
#
#   Since 2007 has your family / have your parents experienced any of the following? (select all that apply) - Selected Choice  \
# 0                                                  4
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                  4
#
#   Since 2007 has your family / have your parents experienced any of the following? (select all that apply) - Other financial difficulties (please explain) - Text  \
# 0     Insufficient funds to live at a good standard.
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                            moving to a new country
#
#   What is the zip code of the area where you have spent most time, up until this point in your life?
# 0                                              00233
# 1                                              34109
# 2                                              33071
# 3                                              32828
# 4                                              33027

# %%
demog_subscales = frames['demog'].iloc[:,[0,10,11,12,13,15,17]]
demog_subscales.head()
# Out:
#    Participant Number:  How many hours did you sleep last night?  \
# 0                  201                                       7.0
# 1                  202                                       8.0
# 2                  203                                       6.0
# 3                  146                                       8.0
# 4                  205                                       7.0
#
#   How many hours do you usually sleep each night?  \
# 0                                             7.5
# 1                                               8
# 2                                               8
# 3                                               8
# 4                                             8.5
#
#    What do you feel your stress level is today on a scale from 1 to 9?  \
# 0                                                7.0
# 1                                                1.0
# 2                                                2.0
# 3                                                2.0
# 4                                                5.0
#
#    How does your stress level today compare with your usual stress level?  \
# 0                                                7.0
# 1                                                3.0
# 2                                                5.0
# 3                                                5.0
# 4                                                2.0
#
#   Since 2007 has your family / have your parents experienced any of the following? (select all that apply) - Selected Choice  \
# 0                                                  4
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                  4
#
#   What is the zip code of the area where you have spent most time, up until this point in your life?
# 0                                              00233
# 1                                              34109
# 2                                              33071
# 3                                              32828
# 4                                              33027

# %% [markdown]
# ### Sleep and Stress relative scoring

# %%
def score_relative_stress(row):
    if row[4] < 5: return -1
    if row[4] > 5: return 1
    if row[4] == 5: return 0

def numeralize_sleep(row):
    try:
        if isinstance(row[2],basestring) and '-' in row[2]:
            values = row[2].split('-')
            return np.average([float(values[0]),float(values[1])])
        else:
            return float(row[2])
    except ValueError as e:
        print(e)
        return(row[2])

def score_relative_sleep(row):
    try:
        if float(row[1]) < float(row[2]): return -1
        if float(row[1]) > float(row[2]): return 1
        if float(row[1]) == float(row[2]): return 0
    except ValueError as e:
        print(e)
        return('NaN')

# %%
float('6-8, about 7'.split('-')[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-a396c25b4ad5> in <module>()
# ----> 1 float('6-8, about 7'.split('-')[1])
#
# ValueError: invalid literal for float(): 8, about 7

# %%
demog_subscales.iloc[:,2] = demog_subscales.apply(numeralize_sleep,axis=1)
# Out:
# invalid literal for float(): 8, around 7
# invalid literal for float(): 6.5≈7
# C:\Users\ia406477\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
demog_subscales.head()
# Out:
#    Participant Number:  How many hours did you sleep last night?  \
# 0                  201                                       7.0
# 1                  202                                       8.0
# 2                  203                                       6.0
# 3                  146                                       8.0
# 4                  205                                       7.0
#
#   How many hours do you usually sleep each night?  \
# 0                                             7.5
# 1                                               8
# 2                                               8
# 3                                               8
# 4                                             8.5
#
#    What do you feel your stress level is today on a scale from 1 to 9?  \
# 0                                                7.0
# 1                                                1.0
# 2                                                2.0
# 3                                                2.0
# 4                                                5.0
#
#    How does your stress level today compare with your usual stress level?  \
# 0                                                7.0
# 1                                                3.0
# 2                                                5.0
# 3                                                5.0
# 4                                                2.0
#
#   Since 2007 has your family / have your parents experienced any of the following? (select all that apply) - Selected Choice  \
# 0                                                  4
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                  4
#
#   What is the zip code of the area where you have spent most time, up until this point in your life?
# 0                                              00233
# 1                                              34109
# 2                                              33071
# 3                                              32828
# 4                                              33027

# %% [markdown]
# ##### Sleep raw text response caveats
#
# Above, we're trying to convert text responses into parsable float values. Most are of predictable form, with participants typing out a 'range' of hours, but others include special characters and other text, which makes the otherwise workable method of splitting-and-averaging problematic.

# %%
demog_subscales['Relative Stress'] = demog_subscales.apply(score_relative_stress,axis=1)
demog_subscales['Relative Sleep'] = demog_subscales.apply(score_relative_sleep,axis=1)
demog_subscales.head()
# Out:
# invalid literal for float(): 6-8, around 7
# invalid literal for float(): 6.5≈7
# C:\Users\ia406477\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\ia406477\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Participant Number:  How many hours did you sleep last night?  \
# 0                  201                                       7.0
# 1                  202                                       8.0
# 2                  203                                       6.0
# 3                  146                                       8.0
# 4                  205                                       7.0
#
#   How many hours do you usually sleep each night?  \
# 0                                             7.5
# 1                                               8
# 2                                               8
# 3                                               8
# 4                                             8.5
#
#    What do you feel your stress level is today on a scale from 1 to 9?  \
# 0                                                7.0
# 1                                                1.0
# 2                                                2.0
# 3                                                2.0
# 4                                                5.0
#
#    How does your stress level today compare with your usual stress level?  \
# 0                                                7.0
# 1                                                3.0
# 2                                                5.0
# 3                                                5.0
# 4                                                2.0
#
#   Since 2007 has your family / have your parents experienced any of the following? (select all that apply) - Selected Choice  \
# 0                                                  4
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                  4
#
#   What is the zip code of the area where you have spent most time, up until this point in your life?  \
# 0                                              00233
# 1                                              34109
# 2                                              33071
# 3                                              32828
# 4                                              33027
#
#      ZIP  Relative Stress Relative Sleep
# 0  00233              1.0             -1
# 1  34109             -1.0              0
# 2  33071              0.0             -1
# 3  32828              0.0              0
# 4  33027             -1.0             -1

# %% [markdown]
# ### ZIP & SES

# %%
demog_subscales['ZIP'] = demog_subscales.iloc[:,6].apply(str)
demog_subscales.head()
# Out:
# C:\Users\ia406477\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    Participant Number:  How many hours did you sleep last night?  \
# 0                  201                                       7.0
# 1                  202                                       8.0
# 2                  203                                       6.0
# 3                  146                                       8.0
# 4                  205                                       7.0
#
#   How many hours do you usually sleep each night?  \
# 0                                             7.5
# 1                                               8
# 2                                               8
# 3                                               8
# 4                                             8.5
#
#    What do you feel your stress level is today on a scale from 1 to 9?  \
# 0                                                7.0
# 1                                                1.0
# 2                                                2.0
# 3                                                2.0
# 4                                                5.0
#
#    How does your stress level today compare with your usual stress level?  \
# 0                                                7.0
# 1                                                3.0
# 2                                                5.0
# 3                                                5.0
# 4                                                2.0
#
#   Since 2007 has your family / have your parents experienced any of the following? (select all that apply) - Selected Choice  \
# 0                                                  4
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                  4
#
#   What is the zip code of the area where you have spent most time, up until this point in your life?  \
# 0                                              00233
# 1                                              34109
# 2                                              33071
# 3                                              32828
# 4                                              33027
#
#      ZIP  Relative Stress Relative Sleep
# 0  00233              1.0             -1
# 1  34109             -1.0              0
# 2  33071              0.0             -1
# 3  32828              0.0              0
# 4  33027             -1.0             -1

# %% [markdown]
# ### Financial Difficulty

# %% [markdown]
# # PANAS

# %%
frames['panas'].head()
# Out:
#    Participant Number:  Interested  Distressed  Excited  Upset  Strong  \
# 0                  201         3.0         1.0      3.0    1.0     2.0
# 1                  202         3.0         1.0      3.0    1.0     4.0
# 2                  203         4.0         1.0      3.0    1.0     3.0
# 3                  146         4.0         1.0      4.0    1.0     4.0
# 4                  205         3.0         4.0      2.0    2.0     2.0
#
#    Guilty  Scared  Hostile  Enthusiastic   ...    Irritable  Alert  Ashamed  \
# 0     1.0     2.0      1.0           4.0   ...          1.0    3.0      1.0
# 1     1.0     1.0      1.0           4.0   ...          1.0    5.0      1.0
# 2     1.0     2.0      1.0           3.0   ...          1.0    5.0      1.0
# 3     1.0     1.0      1.0           3.0   ...          1.0    3.0      1.0
# 4     1.0     3.0      1.0           3.0   ...          4.0    2.0      1.0
#
#    Inspired  Nervous  Determined  Attentive  Jittery  Active  Afraid
# 0       4.0      4.0         3.0        3.0      4.0     4.0     1.0
# 1       3.0      1.0         4.0        5.0      1.0     5.0     1.0
# 2       1.0      2.0         3.0        5.0      2.0     3.0     1.0
# 3       2.0      4.0         4.0        4.0      3.0     4.0     1.0
# 4       4.0      5.0         4.0        2.0      2.0     2.0     2.0
#
# [5 rows x 21 columns]

# %%
pas_columns = [1,3,5,9,10,12,14,16,17,19]
nas_columns = [2,4,6,7,8,11,13,15,18,20]

frames['panas']['PAS'] = frames['panas'].iloc[:,pas_columns].sum(1)
frames['panas']['NAS'] = frames['panas'].iloc[:,nas_columns].sum(1)

# %%
frames['panas'].head()
# Out:
#    Participant Number:  Interested  Distressed  Excited  Upset  Strong  \
# 0                  201         3.0         1.0      3.0    1.0     2.0
# 1                  202         3.0         1.0      3.0    1.0     4.0
# 2                  203         4.0         1.0      3.0    1.0     3.0
# 3                  146         4.0         1.0      4.0    1.0     4.0
# 4                  205         3.0         4.0      2.0    2.0     2.0
#
#    Guilty  Scared  Hostile  Enthusiastic  ...   Ashamed  Inspired  Nervous  \
# 0     1.0     2.0      1.0           4.0  ...       1.0       4.0      4.0
# 1     1.0     1.0      1.0           4.0  ...       1.0       3.0      1.0
# 2     1.0     2.0      1.0           3.0  ...       1.0       1.0      2.0
# 3     1.0     1.0      1.0           3.0  ...       1.0       2.0      4.0
# 4     1.0     3.0      1.0           3.0  ...       1.0       4.0      5.0
#
#    Determined  Attentive  Jittery  Active  Afraid   PAS   NAS
# 0         3.0        3.0      4.0     4.0     1.0  32.0  17.0
# 1         4.0        5.0      1.0     5.0     1.0  39.0  10.0
# 2         3.0        5.0      2.0     3.0     1.0  33.0  13.0
# 3         4.0        4.0      3.0     4.0     1.0  36.0  15.0
# 4         4.0        2.0      2.0     2.0     2.0  26.0  25.0
#
# [5 rows x 23 columns]

# %% [markdown]
# # BISBAS

# %%
frames['bisbas'].head()
# Out:
#    Participant Number:  \
# 0                  201
# 1                  202
# 2                  203
# 3                  146
# 4                  205
#
#    A person's family is the most important thing in life.  \
# 0                                                2.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                2.0
#
#    Even if something bad is about to happen to me, I rarely experience fear or nervousness.  \
# 0                                                3.0
# 1                                                3.0
# 2                                                4.0
# 3                                                3.0
# 4                                                3.0
#
#    I go out of my way to get things I want.  \
# 0                                       2.0
# 1                                       2.0
# 2                                       1.0
# 3                                       2.0
# 4                                       1.0
#
#    When I'm doing well at something I love to keep at it.  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#    I'm always willing to try something new if I think it will be fun.  \
# 0                                                3.0
# 1                                                1.0
# 2                                                1.0
# 3                                                2.0
# 4                                                1.0
#
#    How I dress is important to me.  \
# 0                              1.0
# 1                              2.0
# 2                              2.0
# 3                              2.0
# 4                              2.0
#
#    When I get something I want, I feel excited and energized.  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#    Criticism or scolding hurts me quite a bit.  \
# 0                                          2.0
# 1                                          3.0
# 2                                          2.0
# 3                                          2.0
# 4                                          3.0
#
#    When I want something I usually go all-out to get it.  \
# 0                                                1.0
# 1                                                2.0
# 2                                                2.0
# 3                                                2.0
# 4                                                2.0
#
#                 ...                I often act on the spur of the moment.  \
# 0               ...                                                   3.0
# 1               ...                                                   2.0
# 2               ...                                                   3.0
# 3               ...                                                   3.0
# 4               ...                                                   3.0
#
#    If I think something unpleasant is going to happen I usually get pretty "worked up."  \
# 0                                                3.0
# 1                                                3.0
# 2                                                1.0
# 3                                                3.0
# 4                                                1.0
#
#    I often wonder why people act the way they do.  \
# 0                                             1.0
# 1                                             1.0
# 2                                             1.0
# 3                                             2.0
# 4                                             1.0
#
#    When good things happen to me, it affects me strongly.  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                3.0
# 4                                                1.0
#
#    I feel worried when I think I have done poorly at something important.  \
# 0                                                2.0
# 1                                                2.0
# 2                                                1.0
# 3                                                2.0
# 4                                                1.0
#
#    I crave excitement and new sensations.  \
# 0                                     2.0
# 1                                     1.0
# 2                                     1.0
# 3                                     2.0
# 4                                     1.0
#
#    When I go after something I use a "no holds barred" approach.  \
# 0                                                3.0
# 1                                                2.0
# 2                                                2.0
# 3                                                3.0
# 4                                                2.0
#
#    I have very few fears compared to my friends.  \
# 0                                            2.0
# 1                                            1.0
# 2                                            2.0
# 3                                            3.0
# 4                                            3.0
#
#    It would excite me to win a contest.  I worry about making mistakes.
# 0                                   1.0                             1.0
# 1                                   1.0                             3.0
# 2                                   1.0                             1.0
# 3                                   1.0                             1.0
# 4                                   1.0                             1.0
#
# [5 rows x 25 columns]

# %%
# Reverse-score all data
bisbas_reversed = 5 - frames['bisbas']
# Revert select columns (SSID, #2, #22) to original value
bisbas_reversed.iloc[:,[0,2,22]] = 5 - bisbas_reversed.iloc[:,[0,2,22]] 
bisbas_reversed.head()
# Out:
#    Participant Number:  \
# 0                  201
# 1                  202
# 2                  203
# 3                  146
# 4                  205
#
#    A person's family is the most important thing in life.  \
# 0                                                3.0
# 1                                                4.0
# 2                                                4.0
# 3                                                4.0
# 4                                                3.0
#
#    Even if something bad is about to happen to me, I rarely experience fear or nervousness.  \
# 0                                                3.0
# 1                                                3.0
# 2                                                4.0
# 3                                                3.0
# 4                                                3.0
#
#    I go out of my way to get things I want.  \
# 0                                       3.0
# 1                                       3.0
# 2                                       4.0
# 3                                       3.0
# 4                                       4.0
#
#    When I'm doing well at something I love to keep at it.  \
# 0                                                4.0
# 1                                                4.0
# 2                                                4.0
# 3                                                4.0
# 4                                                4.0
#
#    I'm always willing to try something new if I think it will be fun.  \
# 0                                                2.0
# 1                                                4.0
# 2                                                4.0
# 3                                                3.0
# 4                                                4.0
#
#    How I dress is important to me.  \
# 0                              4.0
# 1                              3.0
# 2                              3.0
# 3                              3.0
# 4                              3.0
#
#    When I get something I want, I feel excited and energized.  \
# 0                                                4.0
# 1                                                4.0
# 2                                                4.0
# 3                                                4.0
# 4                                                4.0
#
#    Criticism or scolding hurts me quite a bit.  \
# 0                                          3.0
# 1                                          2.0
# 2                                          3.0
# 3                                          3.0
# 4                                          2.0
#
#    When I want something I usually go all-out to get it.  \
# 0                                                4.0
# 1                                                3.0
# 2                                                3.0
# 3                                                3.0
# 4                                                3.0
#
#                 ...                I often act on the spur of the moment.  \
# 0               ...                                                   2.0
# 1               ...                                                   3.0
# 2               ...                                                   2.0
# 3               ...                                                   2.0
# 4               ...                                                   2.0
#
#    If I think something unpleasant is going to happen I usually get pretty "worked up."  \
# 0                                                2.0
# 1                                                2.0
# 2                                                4.0
# 3                                                2.0
# 4                                                4.0
#
#    I often wonder why people act the way they do.  \
# 0                                             4.0
# 1                                             4.0
# 2                                             4.0
# 3                                             3.0
# 4                                             4.0
#
#    When good things happen to me, it affects me strongly.  \
# 0                                                4.0
# 1                                                4.0
# 2                                                4.0
# 3                                                2.0
# 4                                                4.0
#
#    I feel worried when I think I have done poorly at something important.  \
# 0                                                3.0
# 1                                                3.0
# 2                                                4.0
# 3                                                3.0
# 4                                                4.0
#
#    I crave excitement and new sensations.  \
# 0                                     3.0
# 1                                     4.0
# 2                                     4.0
# 3                                     3.0
# 4                                     4.0
#
#    When I go after something I use a "no holds barred" approach.  \
# 0                                                2.0
# 1                                                3.0
# 2                                                3.0
# 3                                                2.0
# 4                                                3.0
#
#    I have very few fears compared to my friends.  \
# 0                                            2.0
# 1                                            1.0
# 2                                            2.0
# 3                                            3.0
# 4                                            3.0
#
#    It would excite me to win a contest.  I worry about making mistakes.
# 0                                   4.0                             4.0
# 1                                   4.0                             2.0
# 2                                   4.0                             4.0
# 3                                   4.0                             4.0
# 4                                   4.0                             4.0
#
# [5 rows x 25 columns]

# %%
bas_drive_columns = [3,9,12,21]
bas_funseeking_columns = [5,10,15,20]
bas_rewardresp_columns = [4,7,14,18,23]
bis_columns = [2,8,13,16,19,22,24]
filler_columns = [1,6,11,17]

frames['bisbas']['BAS Drive'] = bisbas_reversed.iloc[:,bas_drive_columns].sum(1)
frames['bisbas']['BAS Fun Seeking'] = bisbas_reversed.iloc[:,bas_funseeking_columns].sum(1)
frames['bisbas']['BAS Reward Responsiveness'] = bisbas_reversed.iloc[:,bas_rewardresp_columns].sum(1)
frames['bisbas']['BIS'] = bisbas_reversed.iloc[:,bis_columns].sum(1)

frames['bisbas'].head()
# Out:
#    Participant Number:  \
# 0                  201
# 1                  202
# 2                  203
# 3                  146
# 4                  205
#
#    A person's family is the most important thing in life.  \
# 0                                                2.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                2.0
#
#    Even if something bad is about to happen to me, I rarely experience fear or nervousness.  \
# 0                                                3.0
# 1                                                3.0
# 2                                                4.0
# 3                                                3.0
# 4                                                3.0
#
#    I go out of my way to get things I want.  \
# 0                                       2.0
# 1                                       2.0
# 2                                       1.0
# 3                                       2.0
# 4                                       1.0
#
#    When I'm doing well at something I love to keep at it.  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#    I'm always willing to try something new if I think it will be fun.  \
# 0                                                3.0
# 1                                                1.0
# 2                                                1.0
# 3                                                2.0
# 4                                                1.0
#
#    How I dress is important to me.  \
# 0                              1.0
# 1                              2.0
# 2                              2.0
# 3                              2.0
# 4                              2.0
#
#    When I get something I want, I feel excited and energized.  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#    Criticism or scolding hurts me quite a bit.  \
# 0                                          2.0
# 1                                          3.0
# 2                                          2.0
# 3                                          2.0
# 4                                          3.0
#
#    When I want something I usually go all-out to get it.  ...   \
# 0                                                1.0      ...
# 1                                                2.0      ...
# 2                                                2.0      ...
# 3                                                2.0      ...
# 4                                                2.0      ...
#
#    I feel worried when I think I have done poorly at something important.  \
# 0                                                2.0
# 1                                                2.0
# 2                                                1.0
# 3                                                2.0
# 4                                                1.0
#
#    I crave excitement and new sensations.  \
# 0                                     2.0
# 1                                     1.0
# 2                                     1.0
# 3                                     2.0
# 4                                     1.0
#
#    When I go after something I use a "no holds barred" approach.  \
# 0                                                3.0
# 1                                                2.0
# 2                                                2.0
# 3                                                3.0
# 4                                                2.0
#
#    I have very few fears compared to my friends.  \
# 0                                            2.0
# 1                                            1.0
# 2                                            2.0
# 3                                            3.0
# 4                                            3.0
#
#    It would excite me to win a contest.  I worry about making mistakes.  \
# 0                                   1.0                             1.0
# 1                                   1.0                             3.0
# 2                                   1.0                             1.0
# 3                                   1.0                             1.0
# 4                                   1.0                             1.0
#
#    BAS Drive  BAS Fun Seeking  BAS Reward Responsiveness   BIS
# 0       12.0              8.0                       20.0  20.0
# 1       13.0             15.0                       20.0  16.0
# 2       13.0             13.0                       20.0  25.0
# 3       12.0             11.0                       17.0  21.0
# 4       14.0             12.0                       19.0  24.0
#
# [5 rows x 29 columns]

# %% [markdown]
# # GDMS

# %%
frames['gdms'].head()
# Out:
#    Participant Number:  I generally make decisions that feel right to me.  \
# 0                  201                                                5.0
# 1                  202                                                5.0
# 2                  203                                                5.0
# 3                  146                                                4.0
# 4                  205                                                5.0
#
#    I rarely make important decisions without consulting other people.  \
# 0                                                2.0
# 1                                                2.0
# 2                                                5.0
# 3                                                4.0
# 4                                                5.0
#
#    My decision making requires careful thought.  \
# 0                                           4.0
# 1                                           5.0
# 2                                           5.0
# 3                                           5.0
# 4                                           5.0
#
#    When making decisions, I do what seems natural at the moment.  \
# 0                                                4.0
# 1                                                5.0
# 2                                                3.0
# 3                                                3.0
# 4                                                3.0
#
#    I generally make important decisions at the last minute.  \
# 0                                                3.0
# 1                                                3.0
# 2                                                4.0
# 3                                                3.0
# 4                                                5.0
#
#    I double-check my information sources to be sure I have the right facts before making decisions.  \
# 0                                                5.0
# 1                                                5.0
# 2                                                4.0
# 3                                                4.0
# 4                                                3.0
#
#    When I make decisions, I tend to rely on my intuition.  \
# 0                                                4.0
# 1                                                5.0
# 2                                                4.0
# 3                                                2.0
# 4                                                5.0
#
#    I generally make snap decisions.  \
# 0                               1.0
# 1                               2.0
# 2                               3.0
# 3                               1.0
# 4                               3.0
#
#    I avoid making important decisions until the pressure is on.  \
# 0                                                3.0
# 1                                                3.0
# 2                                                5.0
# 3                                                3.0
# 4                                                2.0
#
#                                   ...                                  \
# 0                                 ...
# 1                                 ...
# 2                                 ...
# 3                                 ...
# 4                                 ...
#
#    I postpone decision making whenever possible.  \
# 0                                            3.0
# 1                                            1.0
# 2                                            4.0
# 3                                            3.0
# 4                                            3.0
#
#    I usually have a rational basis for making decisions.  \
# 0                                                4.0
# 1                                                5.0
# 2                                                4.0
# 3                                                4.0
# 4                                                5.0
#
#    I often make impulsive decisions.  \
# 0                                2.0
# 1                                2.0
# 2                                3.0
# 3                                1.0
# 4                                4.0
#
#    If I have the support of others, it is easier for me to make important decisions.  \
# 0                                                4.0
# 1                                                2.0
# 2                                                5.0
# 3                                                4.0
# 4                                                5.0
#
#    When making decisions, I rely upon my instincts.  \
# 0                                               3.0
# 1                                               5.0
# 2                                               3.0
# 3                                               4.0
# 4                                               5.0
#
#    When making a decision, I consider various options in specific terms of a specific goal.  \
# 0                                                5.0
# 1                                                5.0
# 2                                                4.0
# 3                                                5.0
# 4                                                5.0
#
#    I often procrastinate when it comes to making important decisions.  \
# 0                                                4.0
# 1                                                1.0
# 2                                                5.0
# 3                                                2.0
# 4                                                2.0
#
#    I often make decisions on the spur of the moment.  \
# 0                                                2.0
# 1                                                3.0
# 2                                                3.0
# 3                                                1.0
# 4                                                2.0
#
#    When I make a decision, it is more important for me to feel the decision is right than to have a rational reason for it.  \
# 0                                                2.0
# 1                                                4.0
# 2                                                3.0
# 3                                                2.0
# 4                                                3.0
#
#    I use the advice of other people in making my important decisions.
# 0                                                5.0
# 1                                                2.0
# 2                                                5.0
# 3                                                3.0
# 4                                                4.0
#
# [5 rows x 26 columns]

# %%
intuitive_dms_cols = [1,7,14,20,24]
dependent_dms_cols = [2,10,15,19,25]
rational_dms_cols = [3,6,11,17,21]
spontaneous_dms_cols = [4,8,13,18,23]
avoidant_dms_cols = [5,9,12,16,22]

# %%
frames['gdms']['Intuitive DMS'] = frames['gdms'].iloc[:,intuitive_dms_cols].sum(1)
frames['gdms']['Dependent DMS'] = frames['gdms'].iloc[:,dependent_dms_cols].sum(1)
frames['gdms']['Rational DMS'] = frames['gdms'].iloc[:,rational_dms_cols].sum(1)
frames['gdms']['Spontaneous DMS'] = frames['gdms'].iloc[:,spontaneous_dms_cols].sum(1)
frames['gdms']['Avoidant DMS'] = frames['gdms'].iloc[:,avoidant_dms_cols].sum(1)

frames['gdms'].head()
# Out:
#    Participant Number:  I generally make decisions that feel right to me.  \
# 0                  201                                                5.0
# 1                  202                                                5.0
# 2                  203                                                5.0
# 3                  146                                                4.0
# 4                  205                                                5.0
#
#    I rarely make important decisions without consulting other people.  \
# 0                                                2.0
# 1                                                2.0
# 2                                                5.0
# 3                                                4.0
# 4                                                5.0
#
#    My decision making requires careful thought.  \
# 0                                           4.0
# 1                                           5.0
# 2                                           5.0
# 3                                           5.0
# 4                                           5.0
#
#    When making decisions, I do what seems natural at the moment.  \
# 0                                                4.0
# 1                                                5.0
# 2                                                3.0
# 3                                                3.0
# 4                                                3.0
#
#    I generally make important decisions at the last minute.  \
# 0                                                3.0
# 1                                                3.0
# 2                                                4.0
# 3                                                3.0
# 4                                                5.0
#
#    I double-check my information sources to be sure I have the right facts before making decisions.  \
# 0                                                5.0
# 1                                                5.0
# 2                                                4.0
# 3                                                4.0
# 4                                                3.0
#
#    When I make decisions, I tend to rely on my intuition.  \
# 0                                                4.0
# 1                                                5.0
# 2                                                4.0
# 3                                                2.0
# 4                                                5.0
#
#    I generally make snap decisions.  \
# 0                               1.0
# 1                               2.0
# 2                               3.0
# 3                               1.0
# 4                               3.0
#
#    I avoid making important decisions until the pressure is on.      ...       \
# 0                                                3.0                 ...
# 1                                                3.0                 ...
# 2                                                5.0                 ...
# 3                                                3.0                 ...
# 4                                                2.0                 ...
#
#    When making a decision, I consider various options in specific terms of a specific goal.  \
# 0                                                5.0
# 1                                                5.0
# 2                                                4.0
# 3                                                5.0
# 4                                                5.0
#
#    I often procrastinate when it comes to making important decisions.  \
# 0                                                4.0
# 1                                                1.0
# 2                                                5.0
# 3                                                2.0
# 4                                                2.0
#
#    I often make decisions on the spur of the moment.  \
# 0                                                2.0
# 1                                                3.0
# 2                                                3.0
# 3                                                1.0
# 4                                                2.0
#
#    When I make a decision, it is more important for me to feel the decision is right than to have a rational reason for it.  \
# 0                                                2.0
# 1                                                4.0
# 2                                                3.0
# 3                                                2.0
# 4                                                3.0
#
#    I use the advice of other people in making my important decisions.  \
# 0                                                5.0
# 1                                                2.0
# 2                                                5.0
# 3                                                3.0
# 4                                                4.0
#
#    Intuitive DMS  Dependent DMS  Rational DMS  Spontaneous DMS  Avoidant DMS
# 0           18.0           21.0          22.0             11.0          16.0
# 1           24.0            8.0          25.0             15.0           9.0
# 2           18.0           25.0          20.0             15.0          23.0
# 3           16.0           17.0          22.0              7.0          13.0
# 4           23.0           22.0          23.0             14.0          14.0
#
# [5 rows x 31 columns]

# %% [markdown]
# # Financial Literacy

# %%
frames['financ'].head()
# Out:
#    Participant Number:  \
# 0                201.0
# 1                202.0
# 2                203.0
# 3                145.0
# 4                204.0
#
#   Imagine you have saved $10,000. You can now invest this money over the next year using two investment options: a U.S. stock index mutual fund which tracks the performance of the U.S. stock market, and a savings account.  The annual return per dollar invested in the stock index fund will be either +40% or -20%, with equal probability. In other words, it is equally likely for each dollar you invest in the stock market, at the end of the one year investment period, you will either have gained 40 cents, or lost 20 cents.  For the savings account, the known and certain rate of return for a one year investment is 5%.  In other words, for each dollar you put in the savings account today, for sure you will gain 5 cents at the end of the one year investment period.  We assume that whatever amount you do not invest in stocks will be invested in the savings account and will earn the risk free rate of return.  Given this information, how much of the $10,000 will you invest in the U.S. stock index fund? Choose the answer that you would be comfortable with if this was a real-life investment decision.  The answer should be a number between $0 and $10,000.  \
# 0                                               2500
# 1                                               5000
# 2                                               6000
# 3                                               2000
# 4                                                500
#
#    Let's say that when you answered the prior question you decided to invest x dollars out of the $10,000 amount in the U.S. stock index fund, and therefore you put ($10,000-x) dollars in the savings account.  Recall that over the next year the rate of return on the stock index fund will be +40% or -20%, with equal probability.  For the savings account, the rate of return is 5% for sure. What is the amount of money you expect to have at the end of this one year investment period?
# 0                                                1.0
# 1                                                1.0
# 2                                                2.0
# 3                                                4.0
# 4                                                1.0

# %%
frames['financ'].iloc[:,2]
# Out:
# 0      1.0
# 1      1.0
# 2      2.0
# 3      4.0
# 4      1.0
# 5      4.0
# 6      3.0
# 7      5.0
# 8      4.0
# 9      1.0
# 10     4.0
# 11     5.0
# 12     2.0
# 13     5.0
# 14     3.0
# 15     3.0
# 16     1.0
# 17     3.0
# 18     2.0
# 19     5.0
# 20     3.0
# 21     1.0
# 22     3.0
# 23     2.0
# 24     1.0
# 25     5.0
# 26     3.0
# 27     2.0
# 28     1.0
# 29     5.0
#       ...
# 203    5.0
# 204    5.0
# 205    3.0
# 206    4.0
# 207    3.0
# 208    1.0
# 209    5.0
# 210    7.0
# 211    3.0
# 212    NaN
# 213    1.0
# 214    3.0
# 215    3.0
# 216    5.0
# 217    4.0
# 218    8.0
# 219    7.0
# 220    3.0
# 221    6.0
# 222    1.0
# 223    5.0
# 224    3.0
# 225    5.0
# 226    5.0
# 227    8.0
# 228    7.0
# 229    1.0
# 230    5.0
# 231    1.0
# 232    3.0
# Name: Let's say that when you answered the prior question you decided to invest x dollars out of the $10,000 amount in the U.S. stock index fund, and therefore you put ($10,000-x) dollars in the savings account.  Recall that over the next year the rate of return on the stock index fund will be +40% or -20%, with equal probability.  For the savings account, the rate of return is 5% for sure. What is the amount of money you expect to have at the end of this one year investment period?, Length: 233, dtype: float64

# %%
def score_financial_literacy(row):
    resp = row[2]
    if resp == 3:
        return 3
    if resp == 4 or resp == 5 or resp == 7:
        return 2
    if resp == 1 or resp == 2 or resp == 8:
        return 1
    if resp == 6:
        return 0

# %%
frames['financ']['FinLit Score'] = frames['financ'].apply(score_financial_literacy,axis=1)

# %%
frames['financ'].head()
# Out:
#    Participant Number:  \
# 0                201.0
# 1                202.0
# 2                203.0
# 3                145.0
# 4                204.0
#
#   Imagine you have saved $10,000. You can now invest this money over the next year using two investment options: a U.S. stock index mutual fund which tracks the performance of the U.S. stock market, and a savings account.  The annual return per dollar invested in the stock index fund will be either +40% or -20%, with equal probability. In other words, it is equally likely for each dollar you invest in the stock market, at the end of the one year investment period, you will either have gained 40 cents, or lost 20 cents.  For the savings account, the known and certain rate of return for a one year investment is 5%.  In other words, for each dollar you put in the savings account today, for sure you will gain 5 cents at the end of the one year investment period.  We assume that whatever amount you do not invest in stocks will be invested in the savings account and will earn the risk free rate of return.  Given this information, how much of the $10,000 will you invest in the U.S. stock index fund? Choose the answer that you would be comfortable with if this was a real-life investment decision.  The answer should be a number between $0 and $10,000.  \
# 0                                               2500
# 1                                               5000
# 2                                               6000
# 3                                               2000
# 4                                                500
#
#    Let's say that when you answered the prior question you decided to invest x dollars out of the $10,000 amount in the U.S. stock index fund, and therefore you put ($10,000-x) dollars in the savings account.  Recall that over the next year the rate of return on the stock index fund will be +40% or -20%, with equal probability.  For the savings account, the rate of return is 5% for sure. What is the amount of money you expect to have at the end of this one year investment period?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                2.0
# 3                                                4.0
# 4                                                1.0
#
#    FinLit Score
# 0           1.0
# 1           1.0
# 2           1.0
# 3           2.0
# 4           1.0

# %% [markdown]
# # Final Subscales

# %%
demog_subscales = demog_subscales[['Participant Number:','ZIP','Relative Sleep','Relative Stress','Financial Difficulty']]
demog_subscales.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-551cb8837372> in <module>()
# ----> 1 demog_subscales = demog_subscales[['Participant Number:','ZIP','Relative Sleep','Relative Stress','Financial Difficulty']]
#       2 demog_subscales.head()
#
# C:\Users\ia406477\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# C:\Users\ia406477\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# C:\Users\ia406477\AppData\Local\Continuum\anaconda2\lib\site-packages\pandas\core\indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1267                 if mask.any():
#    1268                     raise KeyError('{mask} not in index'
# -> 1269                                    .format(mask=objarr[mask]))
#    1270
#    1271                 return _values_from_object(indexer)
#
# KeyError: "['Financial Difficulty'] not in index"

# %%
panas_subscales = frames['panas'][['Participant Number:','PAS','NAS']]
panas_subscales.head()
# Out:
#    Participant Number:   PAS   NAS
# 0                  201  32.0  17.0
# 1                  202  39.0  10.0
# 2                  203  33.0  13.0
# 3                  146  36.0  15.0
# 4                  205  26.0  25.0

# %%
bisbas_subscales = frames['bisbas'][['Participant Number:','BAS Drive','BAS Fun Seeking','BAS Reward Responsiveness','BIS']]
bisbas_subscales.head()
# Out:
#    Participant Number:  BAS Drive  BAS Fun Seeking  BAS Reward Responsiveness  \
# 0                  201       12.0              8.0                       20.0
# 1                  202       13.0             15.0                       20.0
# 2                  203       13.0             13.0                       20.0
# 3                  146       12.0             11.0                       17.0
# 4                  205       14.0             12.0                       19.0
#
#     BIS
# 0  20.0
# 1  16.0
# 2  25.0
# 3  21.0
# 4  24.0

# %%
gdms_subscales = frames['gdms'][['Participant Number:','Intuitive DMS','Rational DMS','Dependent DMS','Spontaneous DMS','Avoidant DMS']]
gdms_subscales.head()
# Out:
#    Participant Number:  Intuitive DMS  Rational DMS  Dependent DMS  \
# 0                  201           18.0          22.0           21.0
# 1                  202           24.0          25.0            8.0
# 2                  203           18.0          20.0           25.0
# 3                  146           16.0          22.0           17.0
# 4                  205           23.0          23.0           22.0
#
#    Spontaneous DMS  Avoidant DMS
# 0             11.0          16.0
# 1             15.0           9.0
# 2             15.0          23.0
# 3              7.0          13.0
# 4             14.0          14.0

# %%
financ_subscale = frames['financ'][['Participant Number:','FinLit Score']]
financ_subscale.head()
# Out:
#    Participant Number:  FinLit Score
# 0                201.0           1.0
# 1                202.0           1.0
# 2                203.0           1.0
# 3                145.0           2.0
# 4                204.0           1.0

# %%
final_output = pd.merge(panas_subscales,bisbas_subscales,'outer')
final_output = final_output.merge(gdms_subscales,'outer')
final_output = final_output.merge(financ_subscale,'outer')
final_output = final_output.rename(columns={'Participant Number:':'ssid'})
final_output.head()
# Out:
#     ssid   PAS   NAS  BAS Drive  BAS Fun Seeking  BAS Reward Responsiveness  \
# 0  201.0  32.0  17.0       12.0              8.0                       20.0
# 1  202.0  39.0  10.0       13.0             15.0                       20.0
# 2  203.0  33.0  13.0       13.0             13.0                       20.0
# 3  146.0  36.0  15.0       12.0             11.0                       17.0
# 4  205.0  26.0  25.0       14.0             12.0                       19.0
#
#     BIS  Intuitive DMS  Rational DMS  Dependent DMS  Spontaneous DMS  \
# 0  20.0           18.0          22.0           21.0             11.0
# 1  16.0           24.0          25.0            8.0             15.0
# 2  25.0           18.0          20.0           25.0             15.0
# 3  21.0           16.0          22.0           17.0              7.0
# 4  24.0           23.0          23.0           22.0             14.0
#
#    Avoidant DMS  FinLit Score
# 0          16.0           1.0
# 1           9.0           1.0
# 2          23.0           1.0
# 3          13.0           0.0
# 4          14.0           2.0

# %%
fpath = os.path.join(output_dir,'all_subscales.csv')
final_output.to_csv(fpath,index=False)
