# %% [markdown]
# # Setup directories

# %%
import os
derivs_dir = os.path.join('..','derivatives')
homog_dir = os.path.join(derivs_dir,'02.homogenized')
source_dir = os.path.join('..','sourcedata')

# %% [markdown]
# # Import dataframes

# %%
import pandas as pd
fpath = os.path.join(homog_dir,'econdec-full_task-main_beh.xlsx')
beh_frame = pd.read_excel(fpath)

# %% [markdown]
# Below, we've cut down the previous behavioral output to only the trial flags we'll need to line up the gaze data in the right place. Gaze data only applies to the 300-series subjects, but `DataFrame.merge()` will handle that well enough later.

# %%
beh_frame[['subjnum','block','trial','choicert','outcomert']]
# Out:
#        subjnum  block  trial   choicert  outcomert
# 0          100      1      1   3.894676   3.753691
# 1          100      1      2  35.754217   4.168566
# 2          100      1      3   3.434285   3.447755
# 3          100      1      4   7.137389   3.527235
# 4          100      1      5   2.181437   2.383216
# 5          100      1      6   3.588618   2.788704
# 6          100      2      1   2.753445   2.643594
# 7          100      2      2   4.421185   2.850693
# 8          100      2      3   2.197728   3.086568
# 9          100      2      4   2.534579   4.209060
# 10         100      2      5   1.600254   4.273109
# 11         100      2      6   3.168912   5.898196
# 12         100      3      1   4.150455   3.807184
# 13         100      3      2   6.587194   3.919787
# 14         100      3      3   2.199391   1.911879
# 15         100      3      4   2.320789   2.484275
# 16         100      3      5   1.430348   3.367716
# 17         100      3      6   3.010332   2.321584
# 18         100      4      1   2.164133   3.662604
# 19         100      4      2   2.061398   3.611659
# 20         100      4      3   1.993468   2.659391
# 21         100      4      4   2.513043   7.252842
# 22         100      4      5   1.292428   3.522351
# 23         100      4      6   2.438091   4.316900
# 24         100      5      1   6.563143   2.920412
# 25         100      5      2   1.613302   4.654215
# 26         100      5      3   2.739029   2.022017
# 27         100      5      4   2.105508   1.758149
# 28         100      5      5   8.663197   1.949966
# 29         100      5      6   1.263138   1.718178
# ...        ...    ...    ...        ...        ...
# 15450      328      4      1   2.854000   1.783000
# 15451      328      4      2   1.732000   3.938000
# 15452      328      4      3   2.039000   3.654000
# 15453      328      4      4   1.056000   2.698000
# 15454      328      4      5   0.817000   2.655000
# 15455      328      4      6   1.185000   2.047000
# 15456      328      1      1   2.806000   1.516000
# 15457      328      1      2   2.029000   2.610000
# 15458      328      1      3   2.226000   2.809000
# 15459      328      1      4   7.837000   1.607000
# 15460      328      1      5   1.998000   1.409000
# 15461      328      1      6   2.368000   2.121000
# 15462      328      6      1   2.905000   2.429000
# 15463      328      6      2   4.641000   1.701000
# 15464      328      6      3   0.843000   2.916000
# 15465      328      6      4   2.385000   2.209000
# 15466      328      6      5   2.720000   1.438000
# 15467      328      6      6   1.205000   1.900000
# 15468      328     10      1   2.048000   2.678000
# 15469      328     10      2   1.343000   2.002000
# 15470      328     10      3   1.755000   2.945000
# 15471      328     10      4   1.846000   2.724000
# 15472      328     10      5   2.493000   1.418000
# 15473      328     10      6   1.850000   3.088000
# 15474      328      3      1   5.809000   4.660000
# 15475      328      3      2   1.191000   1.658000
# 15476      328      3      3   1.269000   2.035000
# 15477      328      3      4   1.264000   1.582000
# 15478      328      3      5   1.745000   1.763000
# 15479      328      3      6   1.798000   2.230000
#
# [15480 rows x 5 columns]

# %%
fpath = os.path.join(source_dir,'raw-gaze-data.xlsx')
choice_gaze_frame = pd.read_excel(fpath, sheet_name=0)
outcome_gaze_frame = pd.read_excel(fpath, sheet_name=1)

# %% [markdown]
# # Extract only the gaze data for main task series
#
# The dataframe contains gaze data for practice trials, where `practice == 1` or `practice == 2`.
#
# It also contains gaze data for the Memory task trials, where `Phase == Fract` or `Phase == Face`.
#
# We'll slice all these rows out, leaving only the relevant main task trials (1-72).

# %%
choice_gaze_frame = choice_gaze_frame[
    choice_gaze_frame['practice']==3
][
    choice_gaze_frame['Phase'] == 'Main Task'
]
# Out:
# C:\Users\ia406477\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
outcome_gaze_frame = outcome_gaze_frame[
    outcome_gaze_frame['practice'] == 3
][
    outcome_gaze_frame['Phase'] == 'Main Task'
]
# Out:
# C:\Users\ia406477\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %% [markdown]
# # Drop irrelevant columns
#
# There is a lot of data here, so we can implicitly select only the columns we need.
#
# We'll rename them to be a little more clear next.

# %%
choice_gaze_frame = choice_gaze_frame[[
    'RECORDING_SESSION_LABEL','TRIAL_LABEL',
    'IA_LABEL','IA_ID',
    'IA_FSA_COUNT_1','IA_FSA_COUNT_2',
    'IA_FSA_COUNT_24','IA_FSA_COUNT_25',
    'IA_FSA_COUNT_26','IA_FSA_COUNT_27',
]]

# %%
outcome_gaze_frame = outcome_gaze_frame[[
    'RECORDING_SESSION_LABEL','TRIAL_LABEL',
    'IA_ID','IA_LABEL',
    'IA_DWELL_TIME'
]]

# %% [markdown]
# # Rename remaining columns
#
# In the choice phase, we need to keep this entire matrix in order to calculate the oscillation rate. Each row represents an on-screen interest area for a given trial, denoted redundantly with `ia-id` and `ia-label`. There are six(6) relevant interest areas during the choice phase, so there are six(6) rows per trial.
#
# The matrix tells us how many times a saccade started in one interest area and ended in another. Each of these is called a "fixation skip" (FSA), starting in that row's interest area, and ending in the interest area denoted by the `fsa-ia-` columns.

# %%
choice_gaze_frame = choice_gaze_frame.rename(columns={
    'RECORDING_SESSION_LABEL':'subjnum',
    'TRIAL_LABEL':'trial',
    'IA_ID':'ia-id',
    'IA_LABEL':'ia-label',
    'IA_DWELL_TIME':'dwell-time',
    'IA_FSA_COUNT_1':'fsa-ia-01',
    'IA_FSA_COUNT_2':'fsa-ia-02',
    'IA_FSA_COUNT_24':'fsa-ia-24',
    'IA_FSA_COUNT_25':'fsa-ia-25',
    'IA_FSA_COUNT_26':'fsa-ia-26',
    'IA_FSA_COUNT_27':'fsa-ia-27'
})

# %%
choice_gaze_frame['trial'] = choice_gaze_frame['trial']-4

# %%
stock_ia_list = [1,24,26]
bond_ia_list = [2,25,27]

def sum_oscillations(row):
    if row['ia-id'] in stock_ia_list:
        return sum([row['fsa-ia-02'],row['fsa-ia-25'],row['fsa-ia-27']])
    elif row['ia-id'] in bond_ia_list:
        return sum([row['fsa-ia-01'],row['fsa-ia-24'],row['fsa-ia-26']])
    
choice_gaze_frame['oscillations'] = choice_gaze_frame.apply(sum_oscillations,axis=1)

# %%
oscillations = choice_gaze_frame.groupby(['subjnum','trial'])
oscillations = oscillations.sum()['oscillations']
oscillations = oscillations.reset_index()
type(oscillations)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # !!! OSCILLATION SUM IS NOT CORRECT !!!
#
# Precedent `econdec-full_task-all.xlsx` must have the correct trial numbers first.

# %%
beh_frame.merge(oscillations,'left')
# Out:
#        block bondfractallocationtype         bondpic   choicert confidence  \
# 0          1                     NaN   fractal9b.jpg   3.894676          8
# 1          1                     NaN   fractal9b.jpg  35.754217          8
# 2          1                     NaN   fractal9b.jpg   3.434285          8
# 3          1                     NaN   fractal9b.jpg   7.137389          7
# 4          1                     NaN   fractal9b.jpg   2.181437          8
# 5          1                     NaN   fractal9b.jpg   3.588618          8
# 6          2                     NaN   fractal5b.jpg   2.753445          7
# 7          2                     NaN   fractal5b.jpg   4.421185          8
# 8          2                     NaN   fractal5b.jpg   2.197728          8
# 9          2                     NaN   fractal5b.jpg   2.534579          8
# 10         2                     NaN   fractal5b.jpg   1.600254          8
# 11         2                     NaN   fractal5b.jpg   3.168912          9
# 12         3                     NaN  fractal24b.jpg   4.150455          6
# 13         3                     NaN  fractal24b.jpg   6.587194          7
# 14         3                     NaN  fractal24b.jpg   2.199391          7
# 15         3                     NaN  fractal24b.jpg   2.320789          8
# 16         3                     NaN  fractal24b.jpg   1.430348          8
# 17         3                     NaN  fractal24b.jpg   3.010332          8
# 18         4                     NaN   fractal2a.jpg   2.164133          7
# 19         4                     NaN   fractal2a.jpg   2.061398          9
# 20         4                     NaN   fractal2a.jpg   1.993468          8
# 21         4                     NaN   fractal2a.jpg   2.513043          8
# 22         4                     NaN   fractal2a.jpg   1.292428          9
# 23         4                     NaN   fractal2a.jpg   2.438091          8
# 24         5                     NaN  fractal19b.jpg   6.563143          7
# 25         5                     NaN  fractal19b.jpg   1.613302          8
# 26         5                     NaN  fractal19b.jpg   2.739029          8
# 27         5                     NaN  fractal19b.jpg   2.105508          8
# 28         5                     NaN  fractal19b.jpg   8.663197          8
# 29         5                     NaN  fractal19b.jpg   1.263138          9
# ...      ...                     ...             ...        ...        ...
# 15450      4                       R  fractal17b.jpg   2.854000          7
# 15451      4                       R  fractal17b.jpg   1.732000          5
# 15452      4                       L  fractal17b.jpg   2.039000          7
# 15453      4                       L  fractal17b.jpg   1.056000          6
# 15454      4                       R  fractal17b.jpg   0.817000          6
# 15455      4                       L  fractal17b.jpg   1.185000          5
# 15456      1                       R   fractal1b.jpg   2.806000          5
# 15457      1                       L   fractal1b.jpg   2.029000          5
# 15458      1                       R   fractal1b.jpg   2.226000          6
# 15459      1                       R   fractal1b.jpg   7.837000          6
# 15460      1                       R   fractal1b.jpg   1.998000          5
# 15461      1                       L   fractal1b.jpg   2.368000          5
# 15462      6                       L  fractal23b.jpg   2.905000          5
# 15463      6                       L  fractal23b.jpg   4.641000          5
# 15464      6                       L  fractal23b.jpg   0.843000          6
# 15465      6                       R  fractal23b.jpg   2.385000          7
# 15466      6                       L  fractal23b.jpg   2.720000          7
# 15467      6                       R  fractal23b.jpg   1.205000          7
# 15468     10                       R  fractal21a.jpg   2.048000          5
# 15469     10                       L  fractal21a.jpg   1.343000          6
# 15470     10                       L  fractal21a.jpg   1.755000          5
# 15471     10                       R  fractal21a.jpg   1.846000          6
# 15472     10                       L  fractal21a.jpg   2.493000          5
# 15473     10                       R  fractal21a.jpg   1.850000          6
# 15474      3                       R   fractal2a.jpg   5.809000          6
# 15475      3                       L   fractal2a.jpg   1.191000          6
# 15476      3                       L   fractal2a.jpg   1.269000          6
# 15477      3                       L   fractal2a.jpg   1.264000          8
# 15478      3                       L   fractal2a.jpg   1.745000          7
# 15479      3                       L   fractal2a.jpg   1.798000          8
#
#       cueonleft cueonright domain estimation  esttaskrt      ...       \
# 0             b          s   LOSS         50   6.077591      ...
# 1             s          b   LOSS         30   7.294263      ...
# 2             s          b   LOSS         30   7.635041      ...
# 3             b          s   LOSS         40  10.879553      ...
# 4             s          b   LOSS         60  16.525458      ...
# 5             s          b   LOSS         60   9.883486      ...
# 6             s          b   GAIN         30   8.401789      ...
# 7             s          b   GAIN         30   4.590491      ...
# 8             b          s   GAIN         30   6.479625      ...
# 9             s          b   GAIN         20   4.909891      ...
# 10            b          s   GAIN         20   5.826993      ...
# 11            s          b   GAIN         10   2.311530      ...
# 12            b          s   LOSS         60  10.044176      ...
# 13            b          s   LOSS         60   5.503723      ...
# 14            b          s   LOSS         60   9.322087      ...
# 15            s          b   LOSS         70   4.407446      ...
# 16            b          s   LOSS         70   8.752787      ...
# 17            s          b   LOSS         80   4.412722      ...
# 18            b          s   GAIN         50  15.792828      ...
# 19            b          s   GAIN         50   2.442632      ...
# 20            s          b   GAIN         40   3.824663      ...
# 21            s          b   GAIN         40   5.144063      ...
# 22            b          s   GAIN         30   6.667187      ...
# 23            s          b   GAIN         40   3.836336      ...
# 24            b          s   GAIN         50   3.913838      ...
# 25            b          s   GAIN         60   7.392744      ...
# 26            b          s   GAIN         70   2.324250      ...
# 27            b          s   GAIN         60   1.841576      ...
# 28            s          b   GAIN         70   4.351161      ...
# 29            s          b   GAIN         80   1.449237      ...
# ...         ...        ...    ...        ...        ...      ...
# 15450       NaN        NaN   GAIN         60        NaN      ...
# 15451       NaN        NaN   GAIN         50        NaN      ...
# 15452       NaN        NaN   GAIN         60        NaN      ...
# 15453       NaN        NaN   GAIN         70        NaN      ...
# 15454       NaN        NaN   GAIN         70        NaN      ...
# 15455       NaN        NaN   GAIN         65        NaN      ...
# 15456       NaN        NaN   LOSS         40        NaN      ...
# 15457       NaN        NaN   LOSS         30        NaN      ...
# 15458       NaN        NaN   LOSS         40        NaN      ...
# 15459       NaN        NaN   LOSS         50        NaN      ...
# 15460       NaN        NaN   LOSS         30        NaN      ...
# 15461       NaN        NaN   LOSS         35        NaN      ...
# 15462       NaN        NaN   GAIN         30        NaN      ...
# 15463       NaN        NaN   GAIN         30        NaN      ...
# 15464       NaN        NaN   GAIN         20        NaN      ...
# 15465       NaN        NaN   GAIN         15        NaN      ...
# 15466       NaN        NaN   GAIN         15        NaN      ...
# 15467       NaN        NaN   GAIN         15        NaN      ...
# 15468       NaN        NaN   GAIN         40        NaN      ...
# 15469       NaN        NaN   GAIN         30        NaN      ...
# 15470       NaN        NaN   GAIN         30        NaN      ...
# 15471       NaN        NaN   GAIN         40        NaN      ...
# 15472       NaN        NaN   GAIN         50        NaN      ...
# 15473       NaN        NaN   GAIN         60        NaN      ...
# 15474       NaN        NaN   LOSS         50        NaN      ...
# 15475       NaN        NaN   LOSS         60        NaN      ...
# 15476       NaN        NaN   LOSS         50        NaN      ...
# 15477       NaN        NaN   LOSS         60        NaN      ...
# 15478       NaN        NaN   LOSS         60        NaN      ...
# 15479       NaN        NaN   LOSS         65        NaN      ...
#
#       stockfractallocationtype        stockpic  stockvalue  study  subjnum  \
# 0                          NaN  fractal16b.jpg         -10      1      100
# 1                          NaN  fractal16b.jpg         -10      1      100
# 2                          NaN  fractal16b.jpg          -2      1      100
# 3                          NaN  fractal16b.jpg          -2      1      100
# 4                          NaN  fractal16b.jpg          -2      1      100
# 5                          NaN  fractal16b.jpg          -2      1      100
# 6                          NaN   fractal4b.jpg           2      1      100
# 7                          NaN   fractal4b.jpg           2      1      100
# 8                          NaN   fractal4b.jpg           2      1      100
# 9                          NaN   fractal4b.jpg           2      1      100
# 10                         NaN   fractal4b.jpg           2      1      100
# 11                         NaN   fractal4b.jpg           2      1      100
# 12                         NaN  fractal20a.jpg          -2      1      100
# 13                         NaN  fractal20a.jpg          -2      1      100
# 14                         NaN  fractal20a.jpg          -2      1      100
# 15                         NaN  fractal20a.jpg          -2      1      100
# 16                         NaN  fractal20a.jpg         -10      1      100
# 17                         NaN  fractal20a.jpg          -2      1      100
# 18                         NaN  fractal13a.jpg          10      1      100
# 19                         NaN  fractal13a.jpg           2      1      100
# 20                         NaN  fractal13a.jpg           2      1      100
# 21                         NaN  fractal13a.jpg           2      1      100
# 22                         NaN  fractal13a.jpg           2      1      100
# 23                         NaN  fractal13a.jpg          10      1      100
# 24                         NaN  fractal11a.jpg          10      1      100
# 25                         NaN  fractal11a.jpg          10      1      100
# 26                         NaN  fractal11a.jpg          10      1      100
# 27                         NaN  fractal11a.jpg           2      1      100
# 28                         NaN  fractal11a.jpg          10      1      100
# 29                         NaN  fractal11a.jpg          10      1      100
# ...                        ...             ...         ...    ...      ...
# 15450                        L   fractal8b.jpg          10      3      328
# 15451                        L   fractal8b.jpg           2      3      328
# 15452                        R   fractal8b.jpg          10      3      328
# 15453                        R   fractal8b.jpg          10      3      328
# 15454                        L   fractal8b.jpg          10      3      328
# 15455                        R   fractal8b.jpg           2      3      328
# 15456                        L  fractal18a.jpg         -10      3      328
# 15457                        R  fractal18a.jpg         -10      3      328
# 15458                        L  fractal18a.jpg          -2      3      328
# 15459                        L  fractal18a.jpg          -2      3      328
# 15460                        L  fractal18a.jpg         -10      3      328
# 15461                        R  fractal18a.jpg          -2      3      328
# 15462                        R  fractal10a.jpg           2      3      328
# 15463                        R  fractal10a.jpg           2      3      328
# 15464                        R  fractal10a.jpg           2      3      328
# 15465                        L  fractal10a.jpg           2      3      328
# 15466                        R  fractal10a.jpg           2      3      328
# 15467                        L  fractal10a.jpg           2      3      328
# 15468                        L   fractal9a.jpg           2      3      328
# 15469                        R   fractal9a.jpg           2      3      328
# 15470                        R   fractal9a.jpg           2      3      328
# 15471                        L   fractal9a.jpg          10      3      328
# 15472                        R   fractal9a.jpg           2      3      328
# 15473                        L   fractal9a.jpg          10      3      328
# 15474                        L   fractal7b.jpg          -2      3      328
# 15475                        R   fractal7b.jpg          -2      3      328
# 15476                        R   fractal7b.jpg          -2      3      328
# 15477                        R   fractal7b.jpg          -2      3      328
# 15478                        R   fractal7b.jpg          -2      3      328
# 15479                        R   fractal7b.jpg          -2      3      328
#
#       trial  trueprob  bondmem  stockmem  oscillations
# 0         1  0.300000      2.0       0.0           NaN
# 1         2  0.155172      2.0       0.0           NaN
# 2         3  0.300000      2.0       0.0           NaN
# 3         4  0.500000      2.0       0.0           NaN
# 4         5  0.700000      2.0       0.0           NaN
# 5         6  0.844828      2.0       0.0           NaN
# 6         1  0.300000      0.0       3.0           NaN
# 7         2  0.155172      0.0       3.0           NaN
# 8         3  0.072973      0.0       3.0           NaN
# 9         4  0.032635      0.0       3.0           NaN
# 10        5  0.014252      0.0       3.0           NaN
# 11        6  0.006158      0.0       3.0           NaN
# 12        1  0.700000     -3.0       2.0           NaN
# 13        2  0.844828     -3.0       2.0           NaN
# 14        3  0.927027     -3.0       2.0           NaN
# 15        4  0.967365     -3.0       2.0           NaN
# 16        5  0.927027     -3.0       2.0           NaN
# 17        6  0.967365     -3.0       2.0           NaN
# 18        1  0.700000      3.0       0.0           NaN
# 19        2  0.500000      3.0       0.0           NaN
# 20        3  0.300000      3.0       0.0           NaN
# 21        4  0.155172      3.0       0.0           NaN
# 22        5  0.072973      3.0       0.0           NaN
# 23        6  0.155172      3.0       0.0           NaN
# 24        1  0.700000      2.0       1.0           NaN
# 25        2  0.844828      2.0       1.0           NaN
# 26        3  0.927027      2.0       1.0           NaN
# 27        4  0.844828      2.0       1.0           NaN
# 28        5  0.927027      2.0       1.0           NaN
# 29        6  0.967365      2.0       1.0           NaN
# ...     ...       ...      ...       ...           ...
# 15450     1  0.700000      NaN       NaN           1.0
# 15451     2  0.500000      NaN       NaN           2.0
# 15452     3  0.700000      NaN       NaN           3.0
# 15453     4  0.844828      NaN       NaN           0.0
# 15454     5  0.927027      NaN       NaN           0.0
# 15455     6  0.844828      NaN       NaN           1.0
# 15456     1  0.300000      NaN       NaN           1.0
# 15457     2  0.155172      NaN       NaN           2.0
# 15458     3  0.300000      NaN       NaN           3.0
# 15459     4  0.500000      NaN       NaN           0.0
# 15460     5  0.300000      NaN       NaN           0.0
# 15461     6  0.500000      NaN       NaN           1.0
# 15462     1  0.300000      NaN       NaN           1.0
# 15463     2  0.155172      NaN       NaN           2.0
# 15464     3  0.072973      NaN       NaN           3.0
# 15465     4  0.032635      NaN       NaN           0.0
# 15466     5  0.014252      NaN       NaN           0.0
# 15467     6  0.006158      NaN       NaN           1.0
# 15468     1  0.300000      NaN       NaN           1.0
# 15469     2  0.155172      NaN       NaN           2.0
# 15470     3  0.072973      NaN       NaN           3.0
# 15471     4  0.155172      NaN       NaN           0.0
# 15472     5  0.072973      NaN       NaN           0.0
# 15473     6  0.155172      NaN       NaN           1.0
# 15474     1  0.700000      NaN       NaN           1.0
# 15475     2  0.844828      NaN       NaN           2.0
# 15476     3  0.927027      NaN       NaN           3.0
# 15477     4  0.967365      NaN       NaN           0.0
# 15478     5  0.985748      NaN       NaN           0.0
# 15479     6  0.993842      NaN       NaN           1.0
#
# [15480 rows x 25 columns]

# %%
outcome_dwell_time = outcome_gaze_frame.rename(columns={
    'RECORDING_SESSION_LABEL':'subjnum',
    'TRIAL_LABEL':'trial',
    'IA_ID':'ia-id',
    'IA_LABEL':'ia-label',
    'IA_DWELL_TIME':'dwell-time'
})

# %%
outcome_dwell_time['trial'] = outcome_dwell_time['trial']-4

# %%
outcome_dwell_time = outcome_dwell_time[outcome_dwell_time['ia-id']==5]

# %%
outcome_dwell_time[['subjnum','trial','dwell-time']]
# Out:
#        subjnum  trial  dwell-time
# 27         301      1         971
# 31         301      2         352
# 35         301      3        1281
# 39         301      4         437
# 43         301      5         371
# 47         301      6         449
# 51         301      7         409
# 55         301      8         467
# 59         301      9         618
# 63         301     10         401
# 67         301     11         437
# 71         301     12         440
# 75         301     13         440
# 79         301     14         530
# 83         301     15         830
# 87         301     16         362
# 91         301     17         533
# 95         301     18         374
# 99         301     19         697
# 103        301     20         459
# 107        301     21         407
# 111        301     22         390
# 115        301     23         521
# 119        301     24         701
# 123        301     25         389
# 127        301     26         384
# 131        301     27         467
# 135        301     28         412
# 139        301     29         496
# 143        301     30         326
# ...        ...    ...         ...
# 18083      328     43         274
# 18087      328     44         312
# 18091      328     45         374
# 18095      328     46         539
# 18099      328     47         315
# 18103      328     48         385
# 18107      328     49         463
# 18111      328     50         284
# 18115      328     51         528
# 18119      328     52         319
# 18123      328     53         389
# 18127      328     54         423
# 18131      328     55         589
# 18135      328     56         413
# 18139      328     57         343
# 18143      328     58         449
# 18147      328     59         258
# 18151      328     60         632
# 18155      328     61        1115
# 18159      328     62         366
# 18163      328     63         309
# 18167      328     64         638
# 18171      328     65         285
# 18175      328     66         343
# 18179      328     67        1846
# 18183      328     68         242
# 18187      328     69         299
# 18191      328     70         422
# 18195      328     71         294
# 18199      328     72         377
#
# [1944 rows x 3 columns]
